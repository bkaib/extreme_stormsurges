# %% [markdown]
# # Example usage
#
# ## Initialize a GeslaDataset object
# Place the `gesla.py` file in your working directory (or elsewhere on your path), and import the `GeslaDataset` class. Selecting and loading data files requires paths to the metadata .csv file and the directory containing the data files. Initialize a `GeslaDataset` object with these paths as follows.

# %%
from gesla import GeslaDataset

meta_file = "resources/gesla/GESLA3_ALL.csv"
data_path = "resources\gesla\GESLA3.0_ALL.zip"

g3 = GeslaDataset(meta_file=meta_file, data_path=data_path)

# %% [markdown]
# ## Load data from a single file
# If you want to work with data from a single record, and you know the filename you want, use the function `file_to_pandas` as follows. The function returns a `pandas.DataFrame` with data and flags, and a `pandas.Series` containing metadata.

# %%
filename = 'degerby-deg-fin-cmems'
data, meta = g3.file_to_pandas(filename)

data
# Out:
#                      sea_level  qc_flag  use_flag
# date_time
# 1971-01-01 00:00:00      0.028        1         1
# 1971-01-01 01:00:00      0.025        1         1
# 1971-01-01 02:00:00      0.021        1         1
# 1971-01-01 03:00:00      0.026        1         1
# 1971-01-01 04:00:00      0.023        1         1
# ...                        ...      ...       ...
# 2020-12-17 03:00:00     -0.106        1         1
# 2020-12-17 04:00:00     -0.100        1         1
# 2020-12-17 05:00:00     -0.084        1         1
# 2020-12-17 06:00:00     -0.079        1         1
# 2020-12-17 07:00:00     -0.076        1         1
#
# [431652 rows x 3 columns]

# %% [markdown]
# ## Load data from a list of files
# If you want to work with data from multiple files, and you know the filenames you want, use the function `files_to_xarray` as follows. The function returns a `xarray.Dataset` object containing data, flags, and metadata.

# %%
filenames = [
    "durban-181a-zaf-uhslc",
    "dutch_harbor_ak-041b-usa-uhslc", 
    "duxbury-8446166-usa-noaa", 
]
xr_dataset = g3.files_to_xarray(filenames)
xr_dataset
# Out:
# <xarray.Dataset>
# Dimensions:                  (station: 3, date_time: 422978)
# Coordinates:
#   * station                  (station) int64 0 1 2
#   * date_time                (date_time) datetime64[ns] 1970-09-30T22:00:00 ....
# Data variables: (12/28)
#     sea_level                (station, date_time) float64 0.81 1.23 ... nan nan
#     qc_flag                  (station, date_time) float64 1.0 1.0 ... nan nan
#     use_flag                 (station, date_time) float64 1.0 1.0 ... nan nan
#     file_name                (station) object 'durban-181a-zaf-uhslc' ... 'du...
#     site_name                (station) object 'Durban' ... 'Duxbury'
#     site_code                (station) object '181A' '041B' '8446166'
#     ...                       ...
#     instrument               (station) object 'Unspecified' ... 'Unspecified'
#     precision                (station) object 'Unspecified' ... 'Unspecified'
#     null_value               (station) float64 -100.0 -100.0 -100.0
#     gauge_type               (station) object 'Coastal' 'Coastal' 'Coastal'
#     overall_record_quality   (station) object 'No obvious issues' ... 'No obv...
#     filename                 (station) object 'durban-181a-zaf-uhslc' ... 'du...

# %% [markdown]
# ## Load data from the N closest records to a lat/lon location
# Load data from records close to a particular location using the function `load_N_closest` as follows. Provide a lat/lon location and the number of desired records. The function returns a `xarray.Dataset` object containing data, flags, and metadata.
#
# Note the `UserWarning` that occurs when duplicate timestamps are encountered. The function `file_to_pandas` used to read each individual file keeps only the first of any duplicate timestamps.

# %%
data = g3.load_N_closest(lat=60.0, lon=20.0, N=2)
print(data.file_name.values)
# Out:
# ['foglo_degerby-134252-fin-fmi' 'degerby-deg-fin-cmems']

# %% [markdown]
# ## Load data from the records in a lat/lon range
# Load data from records in a rectangular lat/lon range using the function `load_lat_lon_range` as follows. Provide lat/lon extents of the range. The function returns a `xarray.Dataset` object containing data, flags, and metadata.

# %%
# # Preprocess1 Area ERA5
# # Imposes Memory Error like this
# south_lat = 30 
# north_lat = 80 
# west_lon  = -70   
# east_lon  = 50 

data = g3.load_lat_lon_range(
    south_lat=south_lat,
    north_lat=north_lat,
    west_lon=west_lon,
    east_lon=east_lon,
)
print(data.site_name.values)
# Out:
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file aberdeen-abe-gbr-bodc were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file arun_platform-arn-gbr-cco were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file saint_john-65-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file charlottetown-1700-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file halifax-490-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file pointe_au_pere-2980-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file st_johns-905-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file port_aux_basques-665-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file yarmouth-365-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file riviere_au_renard-2330-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file north_sydney-612-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file argentia-835-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file lower_escuminac-2000-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file sept_iles-2780-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file nain-1430-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file harrington_harbour-2550-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file shediac_bay-1805-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file pictou-1630-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file rimouski-2985-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file cap_aux_meules-1970-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file sainte_anne_des_monts-2935-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file west_ste_modeste-2595-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file tadoussac-3425-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file lark_harbour-2685-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file bedford_institute-491-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file rustico-1915-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file baie_comeau-2840-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file belledune-2145-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file parkers_cove-320-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file point_tupper-576-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file dalhousie-2165-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file bonavista-990-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file rivi_a475re_du_loup-3130-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file boutiliers_point-482-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file qikiqtarjuaq-3980-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file gros_cacouna-3125-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file savage_cove-2633-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file pointe_sapin-1830-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file cape_dor-240-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file anchor_point-2637-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file digby-325-can-meds were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file coruna-coru-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file santander-sant-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file ceuta-ceta-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file algeciras-alge-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file malaga-mala-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file palma-palm-esp-ieo were removed.
#   warnings.warn(
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:78: UserWarning: Duplicate timestamps in file skagsudde-2321-swe-smhi were removed.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\read_gesla.ipynb Cell 10' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=3'>4</a> west_lon  = -70
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=4'>5</a> east_lon  = 50
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=6'>7</a> data = g3.load_lat_lon_range(
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=7'>8</a>     south_lat=south_lat,
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=8'>9</a>     north_lat=north_lat,
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=9'>10</a>     west_lon=west_lon,
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=10'>11</a>     east_lon=east_lon,
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=11'>12</a> )
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/read_gesla.ipynb#ch0000009?line=12'>13</a> print(data.site_name.values)
#
# File d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:193, in GeslaDataset.load_lat_lon_range(self, south_lat, north_lat, west_lon, east_lon, force_xarray)
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=189'>190</a> meta = self.meta.loc[lon_bool & lat_bool]
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=191'>192</a> if (meta.index.size > 1) or force_xarray:
# --> <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=192'>193</a>     return self.files_to_xarray(meta.filename.tolist())
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=194'>195</a> else:
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=195'>196</a>     data, meta = self.file_to_pandas(meta.filename.values[0])
#
# File d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:100, in GeslaDataset.files_to_xarray(self, filenames)
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=88'>89</a> def files_to_xarray(self, filenames):
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=89'>90</a>     """Read a list of GESLA filenames into a xarray.Dataset object. The
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=90'>91</a>     dataset includes variables containing metadata for each record.
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=91'>92</a>
#    (...)
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=96'>97</a>         xarray.Dataset: data, flags, and metadata for each record.
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=97'>98</a>     """
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=98'>99</a>     data = xr.concat(
# --> <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=99'>100</a>         [
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=100'>101</a>             self.file_to_pandas(f, return_meta=False).to_xarray()
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=101'>102</a>             for f in filenames
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=102'>103</a>         ],
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=103'>104</a>         dim="station",
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=104'>105</a>     )
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=106'>107</a>     idx = [
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=107'>108</a>         s.Index for s in self.meta.itertuples() if s.filename in filenames
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=108'>109</a>     ]
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=109'>110</a>     meta = self.meta.loc[idx]
#
# File d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:101, in <listcomp>(.0)
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=88'>89</a> def files_to_xarray(self, filenames):
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=89'>90</a>     """Read a list of GESLA filenames into a xarray.Dataset object. The
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=90'>91</a>     dataset includes variables containing metadata for each record.
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=91'>92</a>
#    (...)
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=96'>97</a>         xarray.Dataset: data, flags, and metadata for each record.
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=97'>98</a>     """
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=98'>99</a>     data = xr.concat(
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=99'>100</a>         [
# --> <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=100'>101</a>             self.file_to_pandas(f, return_meta=False).to_xarray()
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=101'>102</a>             for f in filenames
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=102'>103</a>         ],
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=103'>104</a>         dim="station",
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=104'>105</a>     )
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=106'>107</a>     idx = [
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=107'>108</a>         s.Index for s in self.meta.itertuples() if s.filename in filenames
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=108'>109</a>     ]
#     <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=109'>110</a>     meta = self.meta.loc[idx]
#
# File d:\OneDrive\Alle_Ordner\Coding\Python\master_thesis\gesla.py:68, in GeslaDataset.file_to_pandas(self, filename, return_meta)
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=65'>66</a> with zipfile.ZipFile(self.data_path,'r') as source:
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=66'>67</a>     with source.open(filename, "r") as f:
# ---> <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=67'>68</a>         data = pd.read_csv(
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=68'>69</a>             f,
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=69'>70</a>             skiprows=41,
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=70'>71</a>             names=["date", "time", "sea_level", "qc_flag", "use_flag"],
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=71'>72</a>             sep="\s+",
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=72'>73</a>             parse_dates=[[0, 1]],
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=73'>74</a>             index_col=0,
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=74'>75</a>         )
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=75'>76</a>         if data.index[data.index.duplicated()].size > 0:
#      <a href='file:///d%3A/OneDrive/Alle_Ordner/Coding/Python/master_thesis/gesla.py?line=76'>77</a>             data = data.drop_duplicates()
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=579'>580</a> with parser:
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=580'>581</a>     return parser.read(nrows)
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\readers.py:1250, in TextFileReader.read(self, nrows)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=1247'>1248</a> nrows = validate_integer("nrows", nrows)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=1248'>1249</a> try:
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=1249'>1250</a>     index, columns, col_dict = self._engine.read(nrows)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=1250'>1251</a> except Exception:
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/readers.py?line=1251'>1252</a>     self.close()
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:310, in CParserWrapper.read(self, nrows)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=305'>306</a>         self._check_data_length(names, alldata)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=307'>308</a>     data = {k: v for k, (i, v) in zip(names, data_tups)}
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=309'>310</a>     names, date_data = self._do_date_conversions(names, data)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=310'>311</a>     index, names = self._make_index(date_data, alldata, names)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=312'>313</a> # maybe create a mi on the columns
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\base_parser.py:820, in ParserBase._do_date_conversions(self, names, data)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=811'>812</a> def _do_date_conversions(
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=812'>813</a>     self,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=813'>814</a>     names: Sequence[Hashable] | Index,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=814'>815</a>     data: Mapping[Hashable, ArrayLike] | DataFrame,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=815'>816</a> ) -> tuple[Sequence[Hashable] | Index, Mapping[Hashable, ArrayLike] | DataFrame]:
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=816'>817</a>     # returns data, columns
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=818'>819</a>     if self.parse_dates is not None:
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=819'>820</a>         data, names = _process_date_conversion(
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=820'>821</a>             data,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=821'>822</a>             self._date_conv,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=822'>823</a>             self.parse_dates,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=823'>824</a>             self.index_col,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=824'>825</a>             self.index_names,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=825'>826</a>             names,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=826'>827</a>             keep_date_col=self.keep_date_col,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=827'>828</a>         )
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=829'>830</a>     return names, data
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\base_parser.py:1191, in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1188'>1189</a>     data_dict[colspec] = converter(np.asarray(data_dict[colspec]))
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1189'>1190</a> else:
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1190'>1191</a>     new_name, col, old_names = _try_convert_dates(
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1191'>1192</a>         converter, colspec, data_dict, orig_names
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1192'>1193</a>     )
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1193'>1194</a>     if new_name in data_dict:
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1194'>1195</a>         raise ValueError(f"New date column already in dict {new_name}")
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\base_parser.py:1250, in _try_convert_dates(parser, colspec, data_dict, columns)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1246'>1247</a>     new_name = "_".join([str(x) for x in colnames])
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1247'>1248</a> to_parse = [np.asarray(data_dict[c]) for c in colnames if c in data_dict]
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1249'>1250</a> new_col = parser(*to_parse)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1250'>1251</a> return new_name, new_col, colnames
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\io\parsers\base_parser.py:1070, in _make_date_converter.<locals>.converter(*date_cols)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1066'>1067</a> strs = parsing.concat_date_cols(date_cols)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1068'>1069</a> try:
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1069'>1070</a>     return tools.to_datetime(
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1070'>1071</a>         ensure_object(strs),
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1071'>1072</a>         utc=None,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1072'>1073</a>         dayfirst=dayfirst,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1073'>1074</a>         errors="ignore",
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1074'>1075</a>         infer_datetime_format=infer_datetime_format,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1075'>1076</a>         cache=cache_dates,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1076'>1077</a>     ).to_numpy()
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1078'>1079</a> except ValueError:
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1079'>1080</a>     return tools.to_datetime(
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1080'>1081</a>         parsing.try_parse_dates(strs, dayfirst=dayfirst), cache=cache_dates
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/io/parsers/base_parser.py?line=1081'>1082</a>     )
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\core\tools\datetimes.py:1076, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=1073'>1074</a>         result = _convert_and_box_cache(arg, cache_array)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=1074'>1075</a>     else:
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=1075'>1076</a>         result = convert_listlike(arg, format)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=1076'>1077</a> else:
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=1077'>1078</a>     result = convert_listlike(np.array([arg]), format)[0]
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=399'>400</a> assert format is None or infer_datetime_format
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=400'>401</a> utc = tz == "utc"
# --> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=401'>402</a> result, tz_parsed = objects_to_datetime64ns(
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=402'>403</a>     arg,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=403'>404</a>     dayfirst=dayfirst,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=404'>405</a>     yearfirst=yearfirst,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=405'>406</a>     utc=utc,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=406'>407</a>     errors=errors,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=407'>408</a>     require_iso8601=require_iso8601,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=408'>409</a>     allow_object=True,
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=409'>410</a> )
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=411'>412</a> if tz_parsed is not None:
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=412'>413</a>     # We can take a shortcut since the datetime64 numpy array
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=413'>414</a>     # is in UTC
#     <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/tools/datetimes.py?line=414'>415</a>     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2196'>2197</a> order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2197'>2198</a> try:
# -> <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2198'>2199</a>     result, tz_parsed = tslib.array_to_datetime(
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2199'>2200</a>         data.ravel("K"),
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2200'>2201</a>         errors=errors,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2201'>2202</a>         utc=utc,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2202'>2203</a>         dayfirst=dayfirst,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2203'>2204</a>         yearfirst=yearfirst,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2204'>2205</a>         require_iso8601=require_iso8601,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2205'>2206</a>         allow_mixed=allow_mixed,
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2206'>2207</a>     )
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2207'>2208</a>     result = result.reshape(data.shape, order=order)
#    <a href='file:///d%3A/Programme/miniconda3/envs/dspy38/lib/site-packages/pandas/core/arrays/datetimes.py?line=2208'>2209</a> except ValueError as err:
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File D:\Programme\miniconda3\envs\dspy38\lib\site-packages\pandas\_libs\tslib.pyx:451, in pandas._libs.tslib.array_to_datetime()
#
# MemoryError: Unable to allocate 26.0 MiB for an array with shape (3409859,) and data type datetime64[ns]
